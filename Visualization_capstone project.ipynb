# %% [markdown]
# If you are from a data science background you alll must be familiar with the iris Dataset.
# Iris dataset is considered as the Hello World in Data science.It contains five columns
# Petal Length,Petal width,Sepal Length,Sepal Width and Species Type
# Iris is a flowering plant,the researchers have measured various features of the different

# %%
import numpy as np
import pandas as pd

# %%
#Reading the file
df=pd.read_csv(r'C:\Users\asimk\OneDrive\Documents\Jupyter Notebook files\dataset\Iris.csv')

# %%
df.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape #150 rows ,6 columns
# Out:
# (150, 6)

# %%
#we can see that the dataframe contains 6 columns and 150 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#It is clean dataset
#

# %%
#statistical summary of dataset using describe () method
df.describe()

#
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Display summary statistics for categorical columns (dtype='object')
df.describe(include=['object'])
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %% [markdown]
# The describe( )

# %%
#checking missing values

# %%
#it checks the data,data is missing values or not
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# we can see that no column as any missing data

# %%
#Checking Duplicates

# %%
#drop_duplicates() helps to remove the duplicates values dataset
data=df.drop_duplicates(subset = "Species")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %% [markdown]
# we can see that there are only three unique species

# %%
#it checks the values counts in species ''
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# we can see that  all the species contain an equal amount of rows,so we should not delete any entries.

# %%
#Data Visualization

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Species',data=df)
plt.show()

# %% [markdown]
# we can see that all 3 catagory has equal number of values counts/records

# %%
#Relation between variables

# %% [markdown]
# WE will see the relationship between the sepal length and sepal width and
# also between petal length and petal width.
#
# Ex 1:Comparing sepal Length and Sepal Width

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',
               hue='Species',data=df,)
#legend is the identifier of variables with respect to its color
#placing legend outside the figure
plt.legend(bbox_to_anchor=(1,1),loc=2)

plt.show()

# %% [markdown]
# iris-seotsa-->it higher sepalWidth and  sepalLength is smaller.
# iris-versicolor-->it lies in middle of sepalLength and sepalWidth and closes to virginica.
# iris-virginica-->it is larger in sepalLength and smaller in sepalWidth.

# %%
#Ex-2:Comparing Petal Length and Petal Width

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',
               hue="Species",data=df,)
plt.legend(bbox_to_anchor=(1,1),loc=2)

plt.show()

# %% [markdown]
# Findings:
# iris-seotsa-->It is having very low PetalLength(1-2) and PetalWidth(0-0.7).
# iris-versicolor-->It is having normal/middle range petalLength(2.5-5) and PetalWidth(1-1.5).
# iris-virginica-->It is having higher data in petalLength (4-7) and higher In PetalWidth (1.5-2.5).

# %%
#Histogram

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig,axes=plt.subplots(2,2, figsize=(10,10))

axes[0,0].set_title('Sepal Length')
axes[0,0].hist(df["SepalLengthCm"],bins=7)

axes[0,1].set_title('Sepal width')
axes[0,1].hist(df["SepalWidthCm"],bins=5)

axes[1,0].set_title('Petal Length')
axes[1,0].hist(df["PetalLengthCm"],bins=6)

axes[1,1].set_title('Sepal Length')
axes[1,1].hist(df["PetalLengthCm"],bins=6)
# Out:
# (array([50.,  0., 11., 43., 35., 11.]),
#  array([1.        , 1.98333333, 2.96666667, 3.95      , 4.93333333,
#         5.91666667, 6.9       ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# The Highest Frequency of Sepal length is between 30-35 and which is between (5-5-6).
# The Highest Frequency of Sepal Width is around 70  which is between is (3-3.5).
# The Highest Frequency of Petal length is 50 which is between(1-2).
# The Highest Frequency of Petal Width is 50 which is between (1-2)

# %%
#Handling Corrleation

# %% [markdown]
# Pandas df.corr()  is used to find the pairwise correlation of all columns in the dataframe.
# Any NA values are automatically excluded.
# For any non-numeric data type columns in the dataframe it is ignored.

# %%
data.select_dtypes(include=['number']).corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.624413     -0.654654       0.969909
# SepalLengthCm  0.624413       1.000000     -0.999226       0.795795
# SepalWidthCm  -0.654654      -0.999226      1.000000      -0.818999
# PetalLengthCm  0.969909       0.795795     -0.818999       1.000000
# PetalWidthCm   0.999685       0.643817     -0.673417       0.975713
#
#                PetalWidthCm
# Id                 0.999685
# SepalLengthCm      0.643817
# SepalWidthCm      -0.673417
# PetalLengthCm      0.975713
# PetalWidthCm       1.000000

# %%
#Heatmaps
#the Heatmap is a data visulaization technique that is used to analyze the dataset as colors in two dimensions,
#bascially it shows a correlation between all numeric variables in dataset.
#we plot the above-found corelation using the heatmaps.

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Select only numerical columns
numerical_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix for numerical columns only
correlation_matrix = numerical_df.corr()

print(correlation_matrix)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm",fmt='.2f')
plt.title("Correlation Matrix Heatmap")

plt.show()

# %% [markdown]
# Assignment--
# analyze the data and find the relationship between varaibles
# predict the target varaible(species)

# %%
#Box plots
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset('iris')
df.rename(columns={
    'sepal_length':'SepalLengthCm',
    'sepal_width':'SepalWidthCm',
    'petal_length':'PetalLengthCm',
    'petal_width':'PetalWidthCm',
    'species':'Species'},inplace=True)

#function for boxplot
def graph(y):
    sns.boxplot(x='Species',y=y,data=df)

plt.figure(figsize=(10,10))

#Adding subplots
plt.subplot(221)
graph('SepalLengthCm')

plt.subplot(222)
graph('SepalWidthCm')

plt.subplot(223)
graph('PetalLengthCm')

plt.subplot(224)
graph('PetalWidthCm')

plt.tight_layout()
plt.show()

# %%
#do the boxplot of all sepal and petal
sns.boxplot('SepalWidthCm',data=numerical_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #do the boxplot of all sepal and petal
# ----> 2 sns.boxplot('SepalWidthCm',data=numerical_df)
#
# TypeError: boxplot() got multiple values for argument 'data'

# %%
# IQR 
Q1 = np.percentile(df['SepalWidthCm'], 25, 
                interpolation = 'midpoint') 

Q3 = np.percentile(df['SepalWidthCm'], 75, 
                interpolation = 'midpoint') 
IQR = Q3 - Q1 

print("Old Shape: ", df.shape)
# Out:
# Old Shape:  (150, 6)

# %%
# Upper bound 
upper = np.where(df['SepalWidthCm'] >= (Q3+1.5*IQR)) 

# Lower bound 
lower = np.where(df['SepalWidthCm'] <= (Q1-1.5*IQR)) 

# Removing the Outliers 
df.drop(upper[0], inplace = True) # Remove outliers above upper bound
df.drop(lower[0], inplace = True) # Remove outliers below lower bound

print("New Shape: ", df.shape) 

sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# New Shape:  (146, 6)
# <Axes: xlabel='SepalWidthCm'>

# %%
# IQR 
Q1 = np.percentile(df['SepalLengthCm'], 25, 
                interpolation = 'midpoint') 

Q3 = np.percentile(df['SepalLengthCm'], 75, 
                interpolation = 'midpoint') 
IQR = Q3 - Q1 

print("Old Shape: ", df.shape)
# Out:
# Old Shape:  (146, 6)

# %%
# Upper bound 
upper = np.where(df['SepalLengthCm'] >= (Q3+1.5*IQR)) 

# Lower bound 
lower = np.where(df['SepalLengthCm'] <= (Q1-1.5*IQR)) 

# Removing the Outliers 
df.drop(upper[0], inplace = True) # Remove outliers above upper bound
df.drop(lower[0], inplace = True) # Remove outliers below lower bound

print("New Shape: ", df.shape) 

sns.boxplot(x='SepalLengthCm', data=df)
# Out:
# New Shape:  (146, 6)
# <Axes: xlabel='SepalLengthCm'>

# %% [markdown]
# Assignment 1- analyze the data and find the relationship between variaqbles predict the target variable(specis name).
#
# example if sepal lenth is 122.34 and sepal width is 23.45 and petal lenth is 56.00 , petal width is 34.45 then gthe preducted specis is setosa
#
# Assignment 2 find the outlier in every column , remofve the outlier
